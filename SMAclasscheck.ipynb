# %%
from smabacktester import SMABacktester, MomentBacktester

# %%
tester = SMABacktester("AAPL", 50, 100, "2020-01-01", "2023-09-22")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.159098, -0.037473)

# %%
tester.plot_results()

# %%
from smabacktester import MomentBacktester

# %%
testerMB = MomentBacktester("AAPL", 10, "2023-06-01", "2023-09-22")
testerMB.plot_results()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
testerMB.test_results()
# Out:
# (1.051824, 0.116767)
