# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Apple = yf.download("AAPL",start = "2010-01-01", end ="2023-09-07")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.487533
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.498751
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.395379
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.383556
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.425995
# ...                ...         ...         ...         ...         ...
# 2023-08-30  184.940002  187.850006  184.740005  187.649994  187.649994
# 2023-08-31  187.839996  189.119995  187.479996  187.869995  187.869995
# 2023-09-01  189.490005  189.919998  188.279999  189.460007  189.460007
# 2023-09-05  188.279999  189.979996  187.610001  189.699997  189.699997
# 2023-09-06  188.399994  188.850006  181.470001  182.910004  182.910004
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# 2010-01-07  477131200
# 2010-01-08  447610800
# ...               ...
# 2023-08-30   60813900
# 2023-08-31   60794500
# 2023-09-01   45732600
# 2023-09-05   45280000
# 2023-09-06   81755800
#
# [3442 rows x 6 columns]

# %%
ticker = ["SPY", "AAPL", "KO"]

# %%
stocks = yf.download(ticker,start = "2010-01-01", end ="2021-01-01")
stocks
# Out:
# [*********************100%%**********************]  3 of 3 completed
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487531  18.645317   87.483208    7.643214  28.520000
# 2010-01-05    6.498750  18.419764   87.714806    7.656429  28.174999
# 2010-01-06    6.395378  18.413223   87.776527    7.534643  28.165001
# 2010-01-07    6.383557  18.367464   88.147072    7.520714  28.094999
# 2010-01-08    6.425997  18.027510   88.440399    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850601  49.167515  354.399078  131.970001  53.439999
# 2020-12-28  134.494781  49.829948  357.443695  136.690002  54.160000
# 2020-12-29  132.704010  49.802353  356.761749  134.869995  54.130001
# 2020-12-30  131.572479  50.087566  357.270782  133.720001  54.439999
# 2020-12-31  130.559021  50.455585  359.085968  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# 2020-12-31  373.880005  134.740005  54.930000  374.660004  131.720001
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2020-12-24  53.020000  367.450012  131.320007  53.020000  368.079987
# 2020-12-28  53.730000  371.070007  133.990005  53.849998  371.739990
# 2020-12-29  54.020000  370.829987  138.050003  54.450001  373.809998
# 2020-12-30  54.029999  371.570007  135.580002  54.049999  372.339996
# 2020-12-31  54.270000  371.230011  134.080002  54.450001  371.779999
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2020-12-24   54930100   3265500   26457900
# 2020-12-28  124486200   9020500   39000400
# 2020-12-29  121047300   8320600   53680500
# 2020-12-30   96452100   8142700   49455300
# 2020-12-31   99116600   8495000   78520700
#
# [2769 rows x 18 columns]

# %%
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.487531  18.645317  87.483208  7.643214  28.520000  113.330002
# 2010-01-05  6.498750  18.419764  87.714806  7.656429  28.174999  113.629997
# 2010-01-06  6.395378  18.413223  87.776527  7.534643  28.165001  113.709999
# 2010-01-07  6.383557  18.367464  88.147072  7.520714  28.094999  114.190002
# 2010-01-08  6.425997  18.027510  88.440399  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# 2010-01-07  7.571429  28.184999  114.330002  7.466071  27.875000  113.180000
# 2010-01-08  7.571429  27.820000  114.620003  7.466429  27.375000  113.660004
#
#                 Open                            Volume
#                 AAPL         KO         SPY       AAPL        KO        SPY
# Date
# 2010-01-04  7.622500  28.580000  112.370003  493729600  13870400  118944600
# 2010-01-05  7.664286  28.424999  113.260002  601904800  23172400  111579900
# 2010-01-06  7.656429  28.174999  113.519997  552160000  19264600  116074400
# 2010-01-07  7.562500  28.165001  113.500000  477131200  13234600  131091100
# 2010-01-08  7.510714  27.730000  113.889999  447610800  28712400  126402800

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1])

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col = [0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487531  18.645317   87.483208    7.643214  28.520000
# 2010-01-05    6.498750  18.419764   87.714806    7.656429  28.174999
# 2010-01-06    6.395378  18.413223   87.776527    7.534643  28.165001
# 2010-01-07    6.383557  18.367464   88.147072    7.520714  28.094999
# 2010-01-08    6.425997  18.027510   88.440399    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850601  49.167515  354.399078  131.970001  53.439999
# 2020-12-28  134.494781  49.829948  357.443695  136.690002  54.160000
# 2020-12-29  132.704010  49.802353  356.761749  134.869995  54.130001
# 2020-12-30  131.572479  50.087566  357.270782  133.720001  54.439999
# 2020-12-31  130.559021  50.455585  359.085968  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# 2020-12-31  373.880005  134.740005  54.930000  374.660004  131.720001
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2020-12-24  53.020000  367.450012  131.320007  53.020000  368.079987
# 2020-12-28  53.730000  371.070007  133.990005  53.849998  371.739990
# 2020-12-29  54.020000  370.829987  138.050003  54.450001  373.809998
# 2020-12-30  54.029999  371.570007  135.580002  54.049999  372.339996
# 2020-12-31  54.270000  371.230011  134.080002  54.450001  371.779999
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2020-12-24   54930100   3265500   26457900
# 2020-12-28  124486200   9020500   39000400
# 2020-12-29  121047300   8320600   53680500
# 2020-12-30   96452100   8142700   49455300
# 2020-12-31   99116600   8495000   78520700
#
# [2769 rows x 18 columns]

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col = [0], parse_dates=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487531  18.645317   87.483208    7.643214  28.520000
# 2010-01-05    6.498750  18.419764   87.714806    7.656429  28.174999
# 2010-01-06    6.395378  18.413223   87.776527    7.534643  28.165001
# 2010-01-07    6.383557  18.367464   88.147072    7.520714  28.094999
# 2010-01-08    6.425997  18.027510   88.440399    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850601  49.167515  354.399078  131.970001  53.439999
# 2020-12-28  134.494781  49.829948  357.443695  136.690002  54.160000
# 2020-12-29  132.704010  49.802353  356.761749  134.869995  54.130001
# 2020-12-30  131.572479  50.087566  357.270782  133.720001  54.439999
# 2020-12-31  130.559021  50.455585  359.085968  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# 2020-12-31  373.880005  134.740005  54.930000  374.660004  131.720001
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2020-12-24  53.020000  367.450012  131.320007  53.020000  368.079987
# 2020-12-28  53.730000  371.070007  133.990005  53.849998  371.739990
# 2020-12-29  54.020000  370.829987  138.050003  54.450001  373.809998
# 2020-12-30  54.029999  371.570007  135.580002  54.049999  372.339996
# 2020-12-31  54.270000  371.230011  134.080002  54.450001  371.779999
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2020-12-24   54930100   3265500   26457900
# 2020-12-28  124486200   9020500   39000400
# 2020-12-29  121047300   8320600   53680500
# 2020-12-30   96452100   8142700   49455300
# 2020-12-31   99116600   8495000   78520700
#
# [2769 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
# convert multiple index to one tuple

stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.604148    32.465223   182.790482    33.777537    41.320121
# std      24.647222     8.248888    69.986182    24.572747     6.808527
# min       5.821836    16.504200    79.593330     6.858929    25.014999
# 25%      15.221347    26.817398   115.346992    17.484285    37.660000
# 50%      24.581589    32.021873   176.694565    26.987499    41.759998
# 75%      40.985561    37.928131   242.913620    43.007500    45.549999
# max     134.494781    53.492123   359.085968   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean    207.676797    34.114230    41.583236   208.716963    33.413543
# std      67.240791    24.895185     6.864731    67.589965    24.220789
# min     102.199997     7.000000    25.150000   103.419998     6.794643
# 25%     141.559998    17.695356    37.919998   142.100006    17.333929
# 50%     205.210007    27.225000    41.980000   206.190002    26.705000
# 75%     265.339996    43.367500    45.799999   267.320007    42.605000
# max     373.880005   138.789993    60.130001   378.459991   134.339996
#
#                                         Open                            \
#                 KO          SPY         AAPL           KO          SPY
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     41.042551   206.475522    33.764375    41.314411   207.648136
# std       6.755616    66.883703    24.561595     6.807492    67.258092
# min      24.735001   101.129997     6.870357    25.110001   103.110001
# 25%      37.419998   140.929993    17.518213    37.700001   141.660004
# 50%      41.529999   204.110001    26.975000    41.750000   204.960007
# 75%      45.310001   263.390015    43.012501    45.549999   265.779999
# max      59.619999   371.570007   138.050003    59.810001   373.809998
#
#              Volume
#                AAPL            KO           SPY
# count  2.769000e+03  2.769000e+03  2.769000e+03
# mean   2.866162e+08  1.502133e+07  1.244573e+08
# std    2.289459e+08  6.716946e+06  7.477756e+07
# min    4.544800e+07  2.996300e+06  2.027000e+07
# 25%    1.211120e+08  1.071810e+07  7.292670e+07
# 50%    2.029972e+08  1.350830e+07  1.045961e+08
# 75%    3.890376e+08  1.751480e+07  1.539926e+08
# max    1.880998e+09  9.896750e+07  7.178287e+08

# %%
close = stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.special import jv
plt.style.context('dark-background')

# %%
close.plot(figsize=(15,8), fontsize=18)
plt.legend(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
close.iloc[0,0]
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0])
# Out:
#                  AAPL        KO       SPY
# Date
# 2010-01-04   1.000000  1.000000  1.000000
# 2010-01-05   1.001729  0.987903  1.002647
# 2010-01-06   0.985795  0.987553  1.003353
# 2010-01-07   0.983973  0.985098  1.007588
# 2010-01-08   0.990514  0.966865  1.010941
# ...               ...       ...       ...
# 2020-12-24  17.266296  1.873773  3.255978
# 2020-12-28  17.883838  1.899018  3.283950
# 2020-12-29  17.645717  1.897966  3.277685
# 2020-12-30  17.495258  1.908836  3.282361
# 2020-12-31  17.360498  1.922861  3.299038
#
# [2769 rows x 3 columns]

# %%
#Normalize data
normclose=close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8), fontsize = 12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame()
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
aapl["%Change"] = aapl.AAPL.div(aapl.lag1)

# %%
aapl["Diff2"]= aapl.AAPL.diff(periods = 1)
aapl
# Out:
#                   AAPL        lag1      Diff   %Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl["%Change2"] = aapl.AAPL.pct_change(periods=1).mul(100)

aapl
# Out:
#                   AAPL        lag1      Diff   %Change     Diff2  %Change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000  0.664833
# ...                ...         ...       ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999 -0.770265
#
# [2769 rows x 6 columns]

# %%
#del aapl["%Change"]
aapl.rename(columns = {"% Change 2":"2 Change"}, inplace = True)
aapl
# Out:
#                   AAPL        lag1      Diff   %Change     Diff2  %Change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000  0.664833
# ...                ...         ...       ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999 -0.770265
#
# [2769 rows x 6 columns]

# %%
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
ret = aapl.AAPL.pct_change().dropna()
ret
# Out:
# Date
# 2010-01-05    0.001729
# 2010-01-06   -0.015906
# 2010-01-07   -0.001849
# 2010-01-08    0.006648
# 2010-01-11   -0.008821
#                 ...
# 2020-12-24    0.007712
# 2020-12-28    0.035766
# 2020-12-29   -0.013315
# 2020-12-30   -0.008527
# 2020-12-31   -0.007703
# Name: AAPL, Length: 2768, dtype: float64

# %%
ret.plot(kind="hist", figsize=(12,8), bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
daily_mean_return=ret.mean()
daily_mean_return

var_daily = ret.var()
var_daily
# Out:
# 0.00031835760944608053

# %%
std_daily=np.sqrt(var_daily)

std_daily
ret.std()
# Out:
# 0.017842578553731534

# %%
annual_mean_ret=daily_mean_return*252
annual_mean_ret
# Out:
# 0.30013444103158887

# %%
ann_var_ret=var_daily*252
ann_var_ret
# Out:
# 0.08022611758041229

# %%
annual_std_retuens=np.sqrt(ann_var_ret)
annual_std_retuens
# Out:
# 0.28324215360784893

# %%
ret.std()*np.sqrt(252)
# Out:
# 0.28324215360784893

# %%
ticker = ["SPY", "AAPL", "KO","IBM","DIS","MSFT"]
stocks = yf.download(ticker,start = "2010-01-01", end ="2021-01-01")
close = stocks.loc[:,"Close"].copy()
normclose=close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8), fontsize = 12)
plt.legend(fontsize=12)
plt.show()
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
ret=close.pct_change().dropna()
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS   2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM   2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO    2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT  2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY   2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary=ret.describe().T.loc[:,["mean","std"]]

# %%
summary["mean"] = summary["mean"] * 252
summary["std"] = summary["std"] * np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# DIS   0.188696  0.249504
# IBM   0.020648  0.224345
# KO    0.075091  0.176009
# MSFT  0.211915  0.254185
# SPY   0.123754  0.173170

# %%
summary.plot.scatter(x="std", y = "mean", figsize=(12,8), s=50, fontsize=15)

for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"] + 0.002, summary.loc[i, "mean"] + 0.002), fontsize=15)

plt.xlabel("Annual Risk", fontsize=15)
plt.ylabel("Annual Return", fontsize=15)
plt.title("Risk/return", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/return')

# %% [markdown]
# ### Correlation and Covariance

# %%
ret.cov()
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.408513  0.436100  0.339213  0.554051  0.659557
# DIS   0.408513  1.000000  0.497775  0.486514  0.480457  0.706726
# IBM   0.436100  0.497775  1.000000  0.502436  0.533130  0.703342
# KO    0.339213  0.486514  0.502436  1.000000  0.429749  0.639324
# MSFT  0.554051  0.480457  0.533130  0.429749  1.000000  0.744601
# SPY   0.659557  0.706726  0.703342  0.639324  0.744601  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap="Reds", annot=True, annot_kws={"size": 20}, vmax=0.6)
plt.show()

# %% [markdown]
# ## Simple Returns and Log Returns

# %%
df = pd.DataFrame(index=[2016,2017,2018], data=[100,50,95], columns=["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
logreturn=np.log(df/df.shift(1))
logreturn
# Out:
#          Price
# 2016       NaN
# 2017 -0.693147
# 2018  0.641854

# %%
logreturn.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturn.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
spy=SPY.Close.to_frame()
spy
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-09-12  445.989990
# 2023-09-13  446.510010
# 2023-09-14  450.359985
# 2023-09-15  443.369995
# 2023-09-18  443.630005
#
# [7714 rows x 1 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
spy_roll=spy.rolling(window=10)
spy_roll=spy_roll.mean()
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-09-12  448.805008
# 2023-09-13  447.480011
# 2023-09-14  447.480011
# 2023-09-15  446.365005
# 2023-09-18  446.104996
#
# [7714 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).min().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  43.93750
# 1993-02-05  43.93750
# 1993-02-08  43.93750
# 1993-02-09  43.93750
# 1993-02-10  43.93750
# 1993-02-11  43.93750
# 1993-02-12  44.25000
# 1993-02-16  43.46875
# 1993-02-17  43.43750
# 1993-02-18  43.40625
# 1993-02-19  43.40625

# %%
spy["SMA50"] = spy.rolling(window=50, min_periods=50).mean()
spy.head(52)
# Out:
#                Close     SMA50
# Date
# 1993-01-29  43.93750       NaN
# 1993-02-01  44.25000       NaN
# 1993-02-02  44.34375       NaN
# 1993-02-03  44.81250       NaN
# 1993-02-04  45.00000       NaN
# 1993-02-05  44.96875       NaN
# 1993-02-08  44.96875       NaN
# 1993-02-09  44.65625       NaN
# 1993-02-10  44.71875       NaN
# 1993-02-11  44.93750       NaN
# 1993-02-12  44.59375       NaN
# 1993-02-16  43.46875       NaN
# 1993-02-17  43.43750       NaN
# 1993-02-18  43.40625       NaN
# 1993-02-19  43.56250       NaN
# 1993-02-22  43.71875       NaN
# 1993-02-23  43.68750       NaN
# 1993-02-24  44.25000       NaN
# 1993-02-25  44.34375       NaN
# 1993-02-26  44.40625       NaN
# 1993-03-01  44.28125       NaN
# 1993-03-02  44.93750       NaN
# 1993-03-03  45.12500       NaN
# 1993-03-04  44.87500       NaN
# 1993-03-05  44.75000       NaN
# 1993-03-08  45.75000       NaN
# 1993-03-09  45.59375       NaN
# 1993-03-10  45.68750       NaN
# 1993-03-11  45.56250       NaN
# 1993-03-12  45.09375       NaN
# 1993-03-15  45.31250       NaN
# 1993-03-16  45.31250       NaN
# 1993-03-17  45.03125       NaN
# 1993-03-18  45.31250       NaN
# 1993-03-19  45.03125       NaN
# 1993-03-22  44.78125       NaN
# 1993-03-23  44.87500       NaN
# 1993-03-24  44.87500       NaN
# 1993-03-25  45.15625       NaN
# 1993-03-26  44.90625       NaN
# 1993-03-29  45.09375       NaN
# 1993-03-30  45.21875       NaN
# 1993-03-31  45.18750       NaN
# 1993-04-01  45.03125       NaN
# 1993-04-02  44.09375       NaN
# 1993-04-05  44.31250       NaN
# 1993-04-06  44.18750       NaN
# 1993-04-07  44.34375       NaN
# 1993-04-08  44.28125       NaN
# 1993-04-12  44.90625  44.68750
# 1993-04-13  45.00000  44.70875
# 1993-04-14  44.93750  44.72250

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
spy["SMA200"] = spy.Close.rolling(window=200, min_periods=200).mean()
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show
plt.title("AAPL 50/200 Moving Average", fontsize=25)
# Out:
# Text(0.5, 1.0, 'AAPL 50/200 Moving Average')

# %%
spy["EMA100"] = spy.Close.ewm(span=100, min_periods=100).mean()
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show
plt.title("AAPL 50/100/200 Moving Average", fontsize=25)
# Out:
# Text(0.5, 1.0, 'AAPL 50/100/200 Moving Average')

# %%
spy["Day"]=spy.index.day_name()
spy["Quarter"] = spy.index.quarter
spy
# Out:
#                  Close       SMA50     SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN        NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN        NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN        NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN        NaN         NaN   Thursday        1
# ...                ...         ...        ...         ...        ...      ...
# 2023-09-12  445.989990  447.072601  416.56135  435.265163    Tuesday        3
# 2023-09-13  446.510010  447.127001  416.78180  435.487833  Wednesday        3
# 2023-09-14  450.359985  447.271601  417.02195  435.782331   Thursday        3
# 2023-09-15  443.369995  447.345801  417.25925  435.932582     Friday        3
# 2023-09-18  443.630005  447.447401  417.50125  436.085006     Monday        3
#
# [7714 rows x 6 columns]

# %%
all_days=pd.date_range(start="1993-01-29",end="2023-09-15", freq="D")
all_days
# Out:
# DatetimeIndex(['1993-01-29', '1993-01-30', '1993-01-31', '1993-02-01',
#                '1993-02-02', '1993-02-03', '1993-02-04', '1993-02-05',
#                '1993-02-06', '1993-02-07',
#                ...
#                '2023-09-06', '2023-09-07', '2023-09-08', '2023-09-09',
#                '2023-09-10', '2023-09-11', '2023-09-12', '2023-09-13',
#                '2023-09-14', '2023-09-15'],
#               dtype='datetime64[ns]', length=11187, freq='D')

# %%
spy=spy.reindex(all_days)
spy
# Out:
#                  Close       SMA50     SMA200      EMA100        Day  Quarter
# 1993-01-29   43.937500         NaN        NaN         NaN     Friday      1.0
# 1993-01-30         NaN         NaN        NaN         NaN        NaN      NaN
# 1993-01-31         NaN         NaN        NaN         NaN        NaN      NaN
# 1993-02-01   44.250000         NaN        NaN         NaN     Monday      1.0
# 1993-02-02   44.343750         NaN        NaN         NaN    Tuesday      1.0
# ...                ...         ...        ...         ...        ...      ...
# 2023-09-11  448.450012  447.018401  416.33090  435.048500     Monday      3.0
# 2023-09-12  445.989990  447.072601  416.56135  435.265163    Tuesday      3.0
# 2023-09-13  446.510010  447.127001  416.78180  435.487833  Wednesday      3.0
# 2023-09-14  450.359985  447.271601  417.02195  435.782331   Thursday      3.0
# 2023-09-15  443.369995  447.345801  417.25925  435.932582     Friday      3.0
#
# [11187 rows x 6 columns]

# %%
spy.fillna(method="ffill")
spy.fillna(method="bfill")
# Out:
# C:\Users\eecvl\AppData\Local\Temp\ipykernel_3340\1056906149.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="ffill")
# C:\Users\eecvl\AppData\Local\Temp\ipykernel_3340\1056906149.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="bfill")
#                  Close       SMA50      SMA200      EMA100        Day  Quarter
# 1993-01-29   43.937500   44.687500   45.205937   44.749197     Friday      1.0
# 1993-01-30   44.250000   44.687500   45.205937   44.749197     Monday      1.0
# 1993-01-31   44.250000   44.687500   45.205937   44.749197     Monday      1.0
# 1993-02-01   44.250000   44.687500   45.205937   44.749197     Monday      1.0
# 1993-02-02   44.343750   44.687500   45.205937   44.749197    Tuesday      1.0
# ...                ...         ...         ...         ...        ...      ...
# 2023-09-11  448.450012  447.018401  416.330900  435.048500     Monday      3.0
# 2023-09-12  445.989990  447.072601  416.561350  435.265163    Tuesday      3.0
# 2023-09-13  446.510010  447.127001  416.781800  435.487833  Wednesday      3.0
# 2023-09-14  450.359985  447.271601  417.021950  435.782331   Thursday      3.0
# 2023-09-15  443.369995  447.345801  417.259250  435.932582     Friday      3.0
#
# [11187 rows x 6 columns]

# %%
SPY=yf.download("SPY",interval="1wk")
SPY
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.941389
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.526785
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.313913
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.728527
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.207485
# ...                ...         ...         ...         ...         ...
# 2023-08-21  437.549988  445.220001  435.000000  439.970001  438.423523
# 2023-08-28  442.239990  453.670013  439.970001  451.190002  449.604095
# 2023-09-04  450.730011  451.059998  442.750000  445.519989  443.954010
# 2023-09-11  448.239990  451.079987  442.920013  443.369995  441.811584
# 2023-09-18  443.049988  444.970001  442.559998  443.630005  443.630005
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# 1993-02-15     998700
# 1993-02-22    1024300
# ...               ...
# 2023-08-21  393065300
# 2023-08-28  338691500
# 2023-09-04  257939800
# 2023-09-11  383137000
# 2023-09-18   55711900
#
# [1600 rows x 6 columns]

# %% [markdown]
# ## Cummulative RETURNS

# %%
apple=yf.download("AAPL")
apple=apple.Close.to_frame()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))
apple.dropna(inplace=True)

# %%
apple.d_returns.sum()
# Out:
# 7.234625013140696

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1386.620836084903

# %%
apple["cummreturns"]=apple.d_returns.cumsum().apply(np.exp)
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2023-09-12  176.300003  -0.017208  1373.609350
# 2023-09-13  174.210007  -0.011926  1357.325524
# 2023-09-14  175.740005   0.008744  1369.246231
# 2023-09-15  175.009995  -0.004163  1363.558483
# 2023-09-18  177.970001   0.016772  1386.620836
#
# [10780 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8),title="Apple buy and hold",fontsize = 12)
# Out:
# <Axes: title={'center': 'Apple buy and hold'}, xlabel='Date'>

# %%
apple.d_returns.mean()*252
# Out:
# 0.169121104203289

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.45288467536474514

# %%
# drawdowns

apple["cummax"] = apple.cummreturns.cummax()
apple
# Out:
#                  Close  d_returns  cummreturns       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2023-09-12  176.300003  -0.017208  1373.609350  1530.604356
# 2023-09-13  174.210007  -0.011926  1357.325524  1530.604356
# 2023-09-14  175.740005   0.008744  1369.246231  1530.604356
# 2023-09-15  175.009995  -0.004163  1363.558483  1530.604356
# 2023-09-18  177.970001   0.016772  1386.620836  1530.604356
#
# [10780 rows x 4 columns]

# %%
apple[["cummreturns","cummax"]].plot(figsize=(12,8),title="Apple buy and hold",fontsize = 12)
# Out:
# <Axes: title={'center': 'Apple buy and hold'}, xlabel='Date'>

# %%
apple["drawdown"] = apple["cummax"] - apple["cummreturns"]
apple
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-09-12  176.300003  -0.017208  1373.609350  1530.604356  156.995006
# 2023-09-13  174.210007  -0.011926  1357.325524  1530.604356  173.278831
# 2023-09-14  175.740005   0.008744  1369.246231  1530.604356  161.358125
# 2023-09-15  175.009995  -0.004163  1363.558483  1530.604356  167.045872
# 2023-09-18  177.970001   0.016772  1386.620836  1530.604356  143.983519
#
# [10780 rows x 5 columns]

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<='2023-01-05')]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple["drawdown"] = (apple["cummax"] - apple["cummreturns"])
apple
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-09-12  176.300003  -0.017208  1373.609350  1530.604356  156.995006
# 2023-09-13  174.210007  -0.011926  1357.325524  1530.604356  173.278831
# 2023-09-14  175.740005   0.008744  1369.246231  1530.604356  161.358125
# 2023-09-15  175.009995  -0.004163  1363.558483  1530.604356  167.045872
# 2023-09-18  177.970001   0.016772  1386.620836  1530.604356  143.983519
#
# [10780 rows x 5 columns]

# %%
apple["drawdown%"] = (apple["cummax"] - apple["cummreturns"])/apple["cummax"]
apple
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-09-12  176.300003  -0.017208  1373.609350  1530.604356  156.995006
# 2023-09-13  174.210007  -0.011926  1357.325524  1530.604356  173.278831
# 2023-09-14  175.740005   0.008744  1369.246231  1530.604356  161.358125
# 2023-09-15  175.009995  -0.004163  1363.558483  1530.604356  167.045872
# 2023-09-18  177.970001   0.016772  1386.620836  1530.604356  143.983519
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# 1980-12-18   0.022934
# 1980-12-19   0.000000
# ...               ...
# 2023-09-12   0.102571
# 2023-09-13   0.113209
# 2023-09-14   0.105421
# 2023-09-15   0.109137
# 2023-09-18   0.094070
#
# [10780 rows x 6 columns]

# %%
apple["drawdown%"].max()
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  d_returns  cummreturns    cummax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# ## SMA Strategy

# %%
data = apple.Close.loc[(apple.index>="1991-01-01")]
data=data.to_frame()
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-09-12  176.300003
# 2023-09-13  174.210007
# 2023-09-14  175.740005
# 2023-09-15  175.009995
# 2023-09-18  177.970001
#
# [8240 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"] = data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()
data
# Out:
#                  Close       sma_s     sma_l
# Date
# 1991-01-02    0.388393         NaN       NaN
# 1991-01-03    0.383929         NaN       NaN
# 1991-01-04    0.386161         NaN       NaN
# 1991-01-07    0.386161         NaN       NaN
# 1991-01-08    0.386161         NaN       NaN
# ...                ...         ...       ...
# 2023-09-12  176.300003  185.732600  181.1690
# 2023-09-13  174.210007  185.367600  181.2446
# 2023-09-14  175.740005  185.055800  181.3518
# 2023-09-15  175.009995  184.719800  181.4486
# 2023-09-18  177.970001  184.465601  181.5906
#
# [8240 rows x 3 columns]

# %%
data.plot(figsize=(12,8), title="AAPLE-SMA{}|SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE-SMA50|SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8), title="AAPLE-SMA{}|SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE-SMA50|SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data["position"] = np.where(data["sma_s"]>data["sma_l"], 1,-1)
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2023-09-12  176.300003  185.732600  181.169000         1
# 2023-09-13  174.210007  185.367600  181.244600         1
# 2023-09-14  175.740005  185.055800  181.351800         1
# 2023-09-15  175.009995  184.719800  181.448600         1
# 2023-09-18  177.970001  184.465601  181.590600         1
#
# [8141 rows x 4 columns]

# %%
data.loc["2023",["sma_s","sma_l","position"]].plot(figsize=(12,8), title="AAPLE-SMA{}|SMA{}".format(sma_s,sma_l), fontsize=12, secondary_y = "position")
# Out:
# <Axes: title={'center': 'AAPLE-SMA50|SMA100'}, xlabel='Date'>

# %%
data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
data
# Out:
#                  Close       sma_s       sma_l  position   returns
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1  0.013209
# ...                ...         ...         ...       ...       ...
# 2023-09-12  176.300003  185.732600  181.169000         1 -0.017208
# 2023-09-13  174.210007  185.367600  181.244600         1 -0.011926
# 2023-09-14  175.740005  185.055800  181.351800         1  0.008744
# 2023-09-15  175.009995  184.719800  181.448600         1 -0.004163
# 2023-09-18  177.970001  184.465601  181.590600         1  0.016772
#
# [8141 rows x 5 columns]

# %%
data["strategy"] = data["returns"]*data.position.shift(1)
data
# Out:
#                  Close       sma_s       sma_l  position   returns  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1       NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1  0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1  0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1  0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1  0.013209  0.013209
# ...                ...         ...         ...       ...       ...       ...
# 2023-09-12  176.300003  185.732600  181.169000         1 -0.017208 -0.017208
# 2023-09-13  174.210007  185.367600  181.244600         1 -0.011926 -0.011926
# 2023-09-14  175.740005  185.055800  181.351800         1  0.008744  0.008744
# 2023-09-15  175.009995  184.719800  181.448600         1 -0.004163 -0.004163
# 2023-09-18  177.970001  184.465601  181.590600         1  0.016772  0.016772
#
# [8141 rows x 6 columns]

# %%
data.dropna(inplace=True)
data[["returns","strategy"]].sum()
# Out:
# returns     6.090677
# strategy    2.128917
# dtype: float64

# %%
data[["returns","strategy"]].sum().apply(np.exp)
# Out:
# returns     441.720314
# strategy      8.405762
# dtype: float64

# %%
data[["returns","strategy"]].std()*np.sqrt(252)
# Out:
# returns     0.436590
# strategy    0.436732
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Strategy with Long Bias

# %%
data["position2"] = np.where(data["sma_s"]>data["sma_l"],1,0)
data["strategy2"] = data["returns"]*data.position2.shift(1)
data.dropna(inplace=True)
data
# Out:
#                  Close       sma_s       sma_l  position   returns  strategy  \
# Date
# 1991-05-28    0.410714    0.527344    0.513806         1  0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1  0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1  0.013209  0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1 -0.013209 -0.013209
# 1991-06-03    0.439732    0.513259    0.515223        -1  0.046761  0.046761
# ...                ...         ...         ...       ...       ...       ...
# 2023-09-12  176.300003  185.732600  181.169000         1 -0.017208 -0.017208
# 2023-09-13  174.210007  185.367600  181.244600         1 -0.011926 -0.011926
# 2023-09-14  175.740005  185.055800  181.351800         1  0.008744  0.008744
# 2023-09-15  175.009995  184.719800  181.448600         1 -0.004163 -0.004163
# 2023-09-18  177.970001  184.465601  181.590600         1  0.016772  0.016772
#
#             position2  strategy2
# Date
# 1991-05-28          1   0.002721
# 1991-05-29          1   0.021507
# 1991-05-30          1   0.013209
# 1991-05-31          1  -0.013209
# 1991-06-03          0   0.046761
# ...               ...        ...
# 2023-09-12          1  -0.017208
# 2023-09-13          1  -0.011926
# 2023-09-14          1   0.008744
# 2023-09-15          1  -0.004163
# 2023-09-18          1   0.016772
#
# [8139 rows x 8 columns]

# %%
data[["returns","strategy2"]].sum()
# Out:
# returns      6.074194
# strategy2    4.093314
# dtype: float64

# %%
data[["returns","strategy2"]].std()*np.sqrt(252)
# Out:
# returns      0.436608
# strategy2    0.337607
# dtype: float64

# %%
## Stragety 2 is better than strategy 1

# %% [markdown]
# ## Creating First Function

# %%
def test_strategy(stock, start, end, SMA):
    df = yf.download(stock, start=start, end=end)
    data = df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"] = data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"] = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)
    data["strategy"] = data["returns"] * data.position.shift(1)
    data.dropna(inplace=True)
    
    ret = np.exp(data["strategy"].sum())
    std = data["strategy"].std() * np.sqrt(252)
    return ret, std

# %%
test_strategy("SPY","2000-01-01", "2023-09-18",(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (4.552785597444819, 0.19613169673607003)

# %% [markdown]
# ## Class

# %%
import yfinance as yf
import numpy as np

class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S  # Corrected here
        self.SMA_L = SMA_L  # Corrected here
        self.start = start
        self.end = end
        self.results = None
        self.get_data()
        
    def get_data(self):  # Added self parameter
        df = yf.download(self.symbol, start=self.start, end=self.end)
        data = df.Close.to_frame()
        data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"] = data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"] = data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2 = data
    
    def test_results(self):
        data = self.data2.copy().dropna()  # Corrected here
        data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)
        data["strategy"] = data["returns"] * data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"] = data["returns"].cumsum().apply(np.exp)
        data["strategyresults"] = data["strategy"].cumsum().apply(np.exp)  # Corrected here
        perf = data["strategyresults"].iloc[-1]  # Corrected here
        outperf = perf - data["returnsbh"].iloc[-1]
        self.results = data
        return round(perf, 6), round(outperf, 6)
        
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title_str = "{} | SMA_S = {} SMA_L = {}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["returnsbh", "strategyresults"]].plot(title=title_str, figsize=(12, 8))  # Corrected here

# %%
tester = SMABacktester("SPY", 50, 100, "2000-01-01", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.592726, 0.297824)

# %%
tester.plot_results()
